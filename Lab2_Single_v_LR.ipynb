# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhumiii27/ML-Labs/blob/main/Lab2_Single_v_LR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("/content/train.csv")

# %%
data
# Out:
#         x          y
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984
# ..    ...        ...
# 695  58.0  58.595006
# 696  93.0  94.625094
# 697  82.0  88.603770
# 698  66.0  63.648685
# 699  97.0  94.975266
#
# [700 rows x 2 columns]

# %%
data.shape
# Out:
# (700, 2)

# %%
data.describe()
# Out:
#                  x           y
# count   700.000000  699.000000
# mean     54.985939   49.939869
# std     134.681703   29.109217
# min       0.000000   -3.839981
# 25%      25.000000   24.929968
# 50%      49.000000   48.973020
# 75%      75.000000   74.929911
# max    3530.157369  108.871618

# %%
#Find box plot for x and y
#Understand the term determinant and why it doesn't exist for a rectangular matrix

# %%
#Splitting the input and output features
x_value=data.iloc[:,0:1]
y_value=data.iloc[:,1:2]
#iloc means integer location based indexing
#i.e select rows/columns using their position (number) rather than their name

# %%
#visualise data
x_box=x_value.boxplot(column=['x'])

# %%
y_box=y_value.boxplot(column=['y'])

# %%
#ML Modeling
#Define the hypothesis
def hypothesis(theta_array,x):
  return (theta_array[0]+theta_array[1]*x)
#return (theta_array[0]+theta_array[1]*x[1]+theta_array[2]*x[2]+theta_array[3]*x[3])

# %% [markdown]
# For multivariable
# (theta_array[0]+theta_array[1]*x[1]+theta_array[2]*x[2]+theta_array[3]*x[3])

# %%
def cost_function(theta_array, x,y,m):
  total_error=0
  for i in range(m):
    total_error+=((theta_array[0]+theta_array[1]*x[i])-y[i])**2
    #total_error+=((theta_array[0]+theta_array[1]*x[1]+theta_array[2]*x[2]+theta_array[3]*x[3])-y[i]))**2
  return (total_error/(2*m))

# %%
# from typing_extensions import TYPE_CHECKING
# def training(x,y,alpha,iters):
#   theta_0,theta_1=0,0
#   theta_array=[theta_0,theta_1]
#   m=x.size
#   for i in range(iters):
#     theta_array=gradient_descent(theta_array,x,y,m,alpha)
#     cost_value=cost_function(theta_array,x,y,m)
#     y_new=theta_array[0]+theta_array[1]*x
#     plt.plot(x,y_new,'r')
#     plt.scatter(x,y, c="turquoise")
#     plt.show()

# %%
def training(x,y,alpha,iters):
  theta_0,theta_1=0,0
  #theta_0,theta_1,theta_2,theta_3=0,0,0,0
  theta_array=[theta_0,theta_1]
  #theta_array=[theta_0,theta_1,theta_2,theta_3]
  m=x.size
  cost_value=[]
  for i in range(iters):
    theta_array=gradient_descent(theta_array,x,y,m,alpha)
    cost_value.append(cost_function(theta_array,x,y,m))
    y_new=theta_array[0]+theta_array[1]*x
    #y_new=theta_array[0]+theta_array[1]*x[1]+theta_array[2]*x[2]+theta_array[3]*x[3]
    plt.plot(x,y_new,'b')
    plt.scatter(x,y, c="turquoise")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.show()
    #Cost Function Graph
    z=np.arange(0,len(cost_value),step=1)
    plt.plot(z,cost_value)
    plt.show()
  return theta_array

# %%
def gradient_descent(theta_array,x,y,m,alpha):
  sum_0,sum_1=0,0
  for i in range(m):
    sum_0+=((theta_array[0]+theta_array[1]*x[i])-y[i])
    sum_1+=x[i]*((theta_array[0]+theta_array[1]*x[i])-y[i])
    # sum_0+=((theta_array[0]+theta_array[1]*x[1]+theta_array[2]*x[2]+theta_array[3]*x[3])-y[i]))
    # sum_1+=x[i]*((theta_array[0]+theta_array[1]*x[1]+theta_array[2]*x[2]+theta_array[3]*x[3])-y[i]))
    # sum_2+=x[i]*((theta_array[0]+theta_array[1]*x[1]+theta_array[2]*x[2]+theta_array[3]*x[3])-y[i])))
    # sum_3+=x[i]*((theta_array[0]+theta_array[1]*x[1]+theta_array[2]*x[2]+theta_array[3]*x[3])-y[i]))
  update_theta0=theta_array[0]-(alpha/m)*sum_0
  update_theta1=theta_array[1]-(alpha/m)*sum_1
  new_theta=[update_theta0,update_theta1]
  return new_theta

# %%
clean_data=data.dropna()
#to drop the missing variable

# %%
clean_data.describe()
# Out:
#                 x           y
# count  699.000000  699.000000
# mean    50.014306   49.939869
# std     28.954560   29.109217
# min      0.000000   -3.839981
# 25%     25.000000   24.929968
# 50%     49.000000   48.973020
# 75%     75.000000   74.929911
# max    100.000000  108.871618

# %%
#Split x and y
x_train=clean_data['x']
y_train=clean_data['y']

# %%
x_t=x_train.values.reshape(x_train.size)
y_t=y_train.values.reshape(y_train.size)

# %%
alpha = 0.0001
# alpha = 0.0000001
# alpha = 0.5
# alpha = 1.0

iters = 50

theta_array = training(x_t, y_t, alpha, iters)

print("Final theta values:", theta_array)
# Out:
# Final theta values: [np.float64(0.014811035918317207), np.float64(0.9988274599652097)]
